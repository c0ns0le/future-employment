# %%
import pandas as pd
import numpy as np

# %%
filepath = '../../../../../../../Data/thesis/core.2008.1.dat'

# %%
pd.read_table(filepath, delimiter='-', nrows = 5)
# Out:
#   000010191280002762008012106200801109710261200201010100010100310032826489120010  \
# 0  0000101912800027620080122072008011097102612002...
# 1  0000101912800027620080123082008011097102612002...
# 2  0000101912800027620080124092008011097102612002...
# 3  0000101912800027620080121062008011097102612002...
# 4  0000101912800027620080122072008011097102612002...
#
#    10  100000000  10.1  10020  1  1.1  1000000001001020  10020.1  1.2  \
# 0  10  100000000    10  10020  1    1  1000000001001020    10020    1
# 1  10  100000000    10  10020  1    1  1000000001001020    10020    1
# 2  10  100000000    10  10020  1    1  1000000001001020    10020    1
# 3  10  100000000    10  10020  1    1  1000000001001020    10020    1
# 4  10  100000000    10  10020  1    1  1000000001001020    10020    1
#
#         ...          1.99   1002  1.100  0010.7  10010           0010.8  \
# 0       ...          1002      1     10   10010     10               10
# ...

# %%
with open(filepath,'r') as f:
    next(f) # skip first row
    df = pd.DataFrame(l.rstrip().split() for l in f)
# Out:
#                                                         0
# 0       0000101912800027620080122072008011097102612002...
# 1       0000101912800027620080123082008011097102612002...
# 2       0000101912800027620080124092008011097102612002...
# 3       0000101912800027620080121062008011097102612002...
# 4       0000101912800027620080122072008011097102612002...
# 5       0000101912800027620080123082008011097102612002...
# 6       0000101912800027620080124092008011097102612002...
# 7       0000101912800027620080121062008011097102612002...
# 8       0000101912800027620080122072008011097102612002...
# 9       0000101912800027620080123082008011097102612002...
# 10      0000101912800027620080124092008011097102612002...
# 11      0000201912800033420080121062008011048109112002...
# 12      0000201912800033420080122072008011048109112002...
# 13      0000201912800033420080123082008011048109112002...
# 14      0000201912800033420080124092008011048109112002...
# ...
